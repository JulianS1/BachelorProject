# %%
import pymc as pm
import pymc_bart as pmb
import numpy as np
import pandas as pd
import arviz as az
import matplotlib.pyplot as plt
from numpy.linalg import inv
import pytensor as pt
import arviz as az
from sklearn.linear_model import LogisticRegression, BayesianRidge, LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.ensemble import RandomForestRegressor
from scipy.stats import gamma
import seaborn as sns
import shap
import itertools
from sklearn.preprocessing import StandardScaler
import openpyxl

# %%
benthicMacrofauna = pd.DataFrame(pd.read_excel("Benthos families.xlsx",  header=[0, 1], index_col=0))
benthicMacrofauna.columns = pd.MultiIndex.from_tuples(
            [(str(col[0]).replace(' ', ''), str(col[1]).replace(' ', '')) for col in benthicMacrofauna.columns]
        )
benthicMacrofauna = benthicMacrofauna.to_frame(index = False)
benthicMacrofauna.index = benthicMacrofauna.index.str.replace(' ', '')

# benthicMacrofauna.drop(index="RowLabels")
benthicMacrofauna = benthicMacrofauna.drop(["RowLabels"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_14500/2182175794.py in ?()
#       1 benthicMacrofauna = pd.DataFrame(pd.read_excel("Benthos families.xlsx",  header=[0, 1], index_col=0))
#       2 benthicMacrofauna.columns = pd.MultiIndex.from_tuples(
#       3             [(str(col[0]).replace(' ', ''), str(col[1]).replace(' ', '')) for col in benthicMacrofauna.columns]
#       4         )
# ----> 5 benthicMacrofauna = benthicMacrofauna.to_frame(index = False)
#       6 benthicMacrofauna.index = benthicMacrofauna.index.str.replace(' ', '')
#       7
#       8 # benthicMacrofauna.drop(index="RowLabels")
#
# ~/miniconda3/envs/pymc-bart/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
# ...

# %%
corr_matrix = benthicMacrofauna.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm")
plt.title("Correlation Matrix of Sediment variables and bioindicators")
# Out:
# Text(0.5, 1.0, 'Correlation Matrix of Sediment variables and bioindicators')
